# %% [markdown]
# #### 工具内部访问 Store（长期记忆）
#
# BaseStore 提供可跨会话持久保存的存储。与 state（短期记忆）不同，保存到该存储中的数据在未来的会话中仍然可用。

# %%
from typing import Any
from langgraph.store.memory import InMemoryStore
from langchain.agents import create_agent
from langchain.tools import tool, ToolRuntime
from langchain.chat_models import init_chat_model
from agent_lab.model_hub import LLM_FAST

# Access memory
@tool
def get_user_info(user_id: str, runtime: ToolRuntime) -> str:
    """Look up user info."""
    store = runtime.store
    user_info = store.get(('users',), user_id)  # type: ignore
    return str(user_info.value) if user_info else 'Unknown user'

# Update memory
@tool
def save_user_info(user_id: str, user_info: dict[str, Any], runtime: ToolRuntime) -> str:
    """Save user info."""
    store = runtime.store
    store.put(('users',), user_id, user_info)  # type: ignore
    return 'Successfully saved user info.'

model = init_chat_model(**LLM_FAST)
store = InMemoryStore()
agent = create_agent(model, tools=[get_user_info, save_user_info], store=store)

# %%
# First session: save user info
res1 = agent.invoke(
    {
        'messages': [
            {
                'role': 'user',
                'content': 'Save the following user: userid: abc123, name: Foo, age: 25, email: foo@langchain.dev',
            }
        ]
    }
)
for msg in res1['messages']:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Save the following user: userid: abc123, name: Foo, age: 25, email: foo@langchain.dev
# ================================== Ai Message ==================================
# Tool Calls:
#   save_user_info (call_00_7cceIJO7uDffPAxJmcamLfEQ)
#  Call ID: call_00_7cceIJO7uDffPAxJmcamLfEQ
#   Args:
#     user_id: abc123
#     user_info: {'name': 'Foo', 'age': 25, 'email': 'foo@langchain.dev'}
# ================================= Tool Message =================================
# Name: save_user_info
#
# Successfully saved user info.
# ================================== Ai Message ==================================
#
# The user with user ID `abc123` has been saved successfully with the following details:
# - **Name:** Foo
# - **Age:** 25
# - **Email:** foo@langchain.dev

# %%
# Second session: get user info
res2 = agent.invoke(
    {'messages': [{'role': 'user', 'content': "Get user info for user with id 'abc123'"}]}
)
for msg in res2['messages']:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Get user info for user with id 'abc123'
# ================================== Ai Message ==================================
# Tool Calls:
#   get_user_info (call_00_WmVRGgtTLZms4Oi5wo6Cy2Po)
#  Call ID: call_00_WmVRGgtTLZms4Oi5wo6Cy2Po
#   Args:
#     user_id: abc123
# ================================= Tool Message =================================
# Name: get_user_info
#
# {'name': 'Foo', 'age': 25, 'email': 'foo@langchain.dev'}
# ================================== Ai Message ==================================
#
# Here is the info for user **abc123**:
#
# - **Name**: Foo
# - **Age**: 25
# - **Email**: foo@langchain.dev
